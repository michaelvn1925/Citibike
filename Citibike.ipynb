# %%
import pandas as pd
import numpy as np

# %%
raw1 = pd.read_csv(r"C:\Users\micha\Documents\uofa-phx-data-pt-02-2020-u-c\02-Homework\20-Tableau\Data1\extracted\JC-201901-citibike-tripdata.csv\JC-201901-citibike-tripdata.csv")
df1 = pd.DataFrame(raw1)
df1.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1           505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2           756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3          1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4          1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id    end station name  \
# 0               -74.033459            3214    Essex Light Rail
# ...

# %%
raw2 = pd.read_csv(r"C:\Users\micha\Documents\uofa-phx-data-pt-02-2020-u-c\02-Homework\20-Tableau\Data1\extracted\JC-201902-citibike-tripdata.csv\JC-201902-citibike-tripdata.csv")
df2 = pd.DataFrame(raw2)
df2.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           142  2019-02-01 15:35:02.0820  2019-02-01 15:37:24.1360
# 1           223  2019-02-01 17:00:46.8900  2019-02-01 17:04:30.5500
# 2           106  2019-02-01 17:08:01.3260  2019-02-01 17:09:47.4400
# 3           370  2019-02-01 17:09:31.2100  2019-02-01 17:15:41.6550
# 4           315  2019-02-01 17:19:53.2490  2019-02-01 17:25:09.1400
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3639       Harborside
# ...

# %%
raw3 = pd.read_csv(r"C:\Users\micha\Documents\uofa-phx-data-pt-02-2020-u-c\02-Homework\20-Tableau\Data1\extracted\JC-201903-citibike-tripdata.csv\JC-201903-citibike-tripdata.csv")
df3 = pd.DataFrame(raw3)
df3.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           306  2019-03-01 06:47:08.2110  2019-03-01 06:52:14.7150
# 1           123  2019-03-01 07:30:53.0220  2019-03-01 07:32:56.7770
# 2           328  2019-03-01 08:18:30.4030  2019-03-01 08:23:59.0590
# 3            95  2019-03-01 11:04:47.2020  2019-03-01 11:06:22.8130
# 4           169  2019-03-01 11:51:29.4170  2019-03-01 11:54:19.2120
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3267     Morris Canal
# ...

# %%
raw4 = pd.read_csv(r"C:\Users\micha\Documents\uofa-phx-data-pt-02-2020-u-c\02-Homework\20-Tableau\Data1\extracted\JC-201904-citibike-tripdata.csv\JC-201904-citibike-tripdata.csv")
df4 = pd.DataFrame(raw4)
df4.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           107  2019-04-01 07:48:04.7540  2019-04-01 07:49:52.3590
# 1           493  2019-04-01 12:41:09.6540  2019-04-01 12:49:23.0290
# 2           512  2019-04-01 14:27:07.9400  2019-04-01 14:35:40.9370
# 3           196  2019-04-01 15:07:38.1510  2019-04-01 15:10:54.6260
# 4           463  2019-04-01 16:19:24.6940  2019-04-01 16:27:08.6450
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3184       Paulus Hook
# ...

# %%
raw5 = pd.read_csv(r"C:\Users\micha\Documents\uofa-phx-data-pt-02-2020-u-c\02-Homework\20-Tableau\Data1\extracted\JC-201905-citibike-tripdata.csv\JC-201905-citibike-tripdata.csv")
df5 = pd.DataFrame(raw5)
df5.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           311  2019-05-01 00:07:36.4670  2019-05-01 00:12:47.6350
# 1           538  2019-05-01 00:08:29.2840  2019-05-01 00:17:27.9410
# 2           178  2019-05-01 00:39:36.4750  2019-05-01 00:42:34.9640
# 3           317  2019-05-01 01:24:28.0220  2019-05-01 01:29:45.5730
# 4           354  2019-05-01 01:54:39.6660  2019-05-01 02:00:34.1750
#
#    start station id start station name  start station latitude  \
# 0              3185          City Hall               40.717733
# 1              3681           Grand St               40.715178
# 2              3638      Washington St               40.724294
# 3              3206            Hilltop               40.731169
# 4              3639         Harborside               40.719252
#
#    start station longitude  end station id end station name  \
# 0               -74.043845            3279      Dixon Mills
# ...

# %%
raw6 = pd.read_csv(r"C:\Users\micha\Documents\uofa-phx-data-pt-02-2020-u-c\02-Homework\20-Tableau\Data1\extracted\JC-201906-citibike-tripdata.csv\JC-201906-citibike-tripdata.csv")
df6 = pd.DataFrame(raw6)
df6.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           316  2019-06-01 00:05:55.7210  2019-06-01 00:11:11.9940
# 1           280  2019-06-01 00:08:09.0920  2019-06-01 00:12:50.0730
# 2          2162  2019-06-01 00:13:11.8800  2019-06-01 00:49:14.3640
# 3          2184  2019-06-01 00:13:30.1110  2019-06-01 00:49:54.2250
# 4           139  2019-06-01 00:13:31.8520  2019-06-01 00:15:51.7880
#
#    start station id start station name  start station latitude  \
# 0              3187          Warren St               40.721124
# 1              3185          City Hall               40.717733
# 2              3199       Newport Pkwy               40.728745
# 3              3199       Newport Pkwy               40.728745
# 4              3207        Oakland Ave               40.737604
#
#    start station longitude  end station id end station name  \
# 0               -74.038051            3199     Newport Pkwy
# ...

# %%
raw7 = pd.read_csv(r"C:\Users\micha\Documents\uofa-phx-data-pt-02-2020-u-c\02-Homework\20-Tableau\Data1\extracted\JC-201907-citibike-tripdata.csv\JC-201907-citibike-tripdata.csv")
df7 = pd.DataFrame(raw7)
df7.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1793  2019-07-01 00:00:36.6150  2019-07-01 00:30:30.5940
# 1           434  2019-07-01 00:02:54.6150  2019-07-01 00:10:09.0370
# 2           251  2019-07-01 00:03:27.5670  2019-07-01 00:07:38.6080
# 3           636  2019-07-01 00:03:56.1690  2019-07-01 00:14:32.4180
# 4           623  2019-07-01 00:04:16.2060  2019-07-01 00:14:40.0500
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3206            Hilltop               40.731169
# 2              3186      Grove St PATH               40.719586
# 3              3206            Hilltop               40.731169
# 4              3206            Hilltop               40.731169
#
#    start station longitude  end station id     end station name  \
# 0               -74.043117            3198     Heights Elevator
# ...

# %%
raw8 = pd.read_csv(r"C:\Users\micha\Documents\uofa-phx-data-pt-02-2020-u-c\02-Homework\20-Tableau\Data1\extracted\JC-201908-citibike-tripdata.csv\JC-201908-citibike-tripdata.csv")
df8 = pd.DataFrame(raw8)
df8.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           261  2019-08-01 00:14:55.9900  2019-08-01 00:19:17.4780
# 1           172  2019-08-01 00:23:06.9910  2019-08-01 00:25:59.1480
# 2           525  2019-08-01 00:23:28.6170  2019-08-01 00:32:13.7000
# 3           219  2019-08-01 00:32:36.1410  2019-08-01 00:36:15.2730
# 4           262  2019-08-01 00:41:26.6700  2019-08-01 00:45:49.3530
#
#    start station id start station name  start station latitude  \
# 0              3205  JC Medical Center               40.716540
# 1              3279        Dixon Mills               40.721630
# 2              3199       Newport Pkwy               40.728745
# 3              3187          Warren St               40.721124
# 4              3186      Grove St PATH               40.719586
#
#    start station longitude  end station id    end station name  \
# 0               -74.049638            3192  Liberty Light Rail
# ...

# %%
raw9 = pd.read_csv(r"C:\Users\micha\Documents\uofa-phx-data-pt-02-2020-u-c\02-Homework\20-Tableau\Data1\extracted\JC-201909-citibike-tripdata.csv\JC-201909-citibike-tripdata.csv")
df9 = pd.DataFrame(raw9)
df9.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           145  2019-09-01 00:00:37.6920  2019-09-01 00:03:03.0100
# 1           212  2019-09-01 00:03:00.6000  2019-09-01 00:06:33.3420
# 2           569  2019-09-01 00:07:13.0020  2019-09-01 00:16:42.8610
# 3          1380  2019-09-01 00:07:25.3350  2019-09-01 00:30:26.1640
# 4          1346  2019-09-01 00:07:56.4670  2019-09-01 00:30:22.5440
#
#    start station id start station name  start station latitude  \
# 0              3640     Journal Square               40.733670
# 1              3194    McGinley Square               40.725340
# 2              3214   Essex Light Rail               40.712774
# 3              3214   Essex Light Rail               40.712774
# 4              3214   Essex Light Rail               40.712774
#
#    start station longitude  end station id            end station name  \
# 0               -74.062500            3206                     Hilltop
# ...

# %%
raw10 = pd.read_csv(r"C:\Users\micha\Documents\uofa-phx-data-pt-02-2020-u-c\02-Homework\20-Tableau\Data1\extracted\JC-201910-citibike-tripdata.csv\JC-201910-citibike-tripdata.csv")
df10 = pd.DataFrame(raw10)
df10.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           892  2019-10-01 00:20:05.0140  2019-10-01 00:34:57.3800
# 1           374  2019-10-01 00:43:48.8790  2019-10-01 00:50:03.8190
# 2           170  2019-10-01 01:35:51.8630  2019-10-01 01:38:42.5470
# 3           946  2019-10-01 02:55:53.4000  2019-10-01 03:11:40.2710
# 4           517  2019-10-01 03:10:16.1290  2019-10-01 03:18:53.6350
#
#    start station id start station name  start station latitude  \
# 0              3275     Columbus Drive               40.718355
# 1              3211         Newark Ave               40.721525
# 2              3194    McGinley Square               40.725340
# 3              3272       Jersey & 3rd               40.723332
# 4              3206            Hilltop               40.731169
#
#    start station longitude  end station id            end station name  \
# 0               -74.038914            3280                 Astor Place
# ...

# %%
raw11 = pd.read_csv(r"C:\Users\micha\Documents\uofa-phx-data-pt-02-2020-u-c\02-Homework\20-Tableau\Data1\extracted\JC-201911-citibike-tripdata.csv\JC-201911-citibike-tripdata.csv")
df11 = pd.DataFrame(raw11)
df11.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           260  2019-11-01 00:02:53.8860  2019-11-01 00:07:14.6450
# 1           285  2019-11-01 00:05:38.6360  2019-11-01 00:10:24.1930
# 2           501  2019-11-01 00:05:43.6310  2019-11-01 00:14:05.4810
# 3           556  2019-11-01 00:07:57.0550  2019-11-01 00:17:13.9010
# 4           321  2019-11-01 00:11:44.5660  2019-11-01 00:17:05.5930
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3206            Hilltop               40.731169
# 2              3186      Grove St PATH               40.719586
# 3              3209       Brunswick St               40.724176
# 4              3273       Manila & 1st               40.721651
#
#    start station longitude  end station id    end station name  \
# 0               -74.043117            3203       Hamilton Park
# ...

# %%
raw12 = pd.read_csv(r"C:\Users\micha\Documents\uofa-phx-data-pt-02-2020-u-c\02-Homework\20-Tableau\Data1\extracted\JC-201912-citibike-tripdata.csv\JC-201912-citibike-tripdata.csv")
df12 = pd.DataFrame(raw12)
df12.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1553  2019-12-01 00:07:13.9360  2019-12-01 00:33:07.6820
# 1           416  2019-12-01 00:16:40.4700  2019-12-01 00:23:36.5700
# 2           294  2019-12-01 00:20:29.7980  2019-12-01 00:25:23.9690
# 3            97  2019-12-01 00:21:13.7580  2019-12-01 00:22:51.5970
# 4           286  2019-12-01 00:29:58.0230  2019-12-01 00:34:44.2280
#
#    start station id start station name  start station latitude  \
# 0              3681           Grand St               40.715178
# 1              3195            Sip Ave               40.730897
# 2              3195            Sip Ave               40.730897
# 3              3202       Newport PATH               40.727224
# 4              3195            Sip Ave               40.730897
#
#    start station longitude  end station id  end station name  \
# 0               -74.037683            3198  Heights Elevator
# ...

# %%
raw13 = pd.read_csv(r"C:\Users\micha\Documents\uofa-phx-data-pt-02-2020-u-c\02-Homework\20-Tableau\Data1\extracted\JC-202001-citibike-tripdata.csv\JC-202001-citibike-tripdata.csv")
df13 = pd.DataFrame(raw13)
df13.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           226  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1           377  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2           288  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3           435  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4           231  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3186      Grove St PATH               40.719586
# 2              3186      Grove St PATH               40.719586
# 3              3195            Sip Ave               40.730897
# 4              3186      Grove St PATH               40.719586
#
#    start station longitude  end station id  end station name  \
# 0               -74.043117            3211        Newark Ave
# ...

# %%
raw14 = pd.read_csv(r"C:\Users\micha\Documents\uofa-phx-data-pt-02-2020-u-c\02-Homework\20-Tableau\Data1\extracted\JC-202002-citibike-tripdata.csv\JC-202002-citibike-tripdata.csv")
df14 = pd.DataFrame(raw14)
df14.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           841  2020-02-01 00:02:13.7650  2020-02-01 00:16:15.4720
# 1           206  2020-02-01 00:16:11.3850  2020-02-01 00:19:37.4460
# 2           859  2020-02-01 00:23:22.1090  2020-02-01 00:37:41.5060
# 3           693  2020-02-01 00:25:14.5170  2020-02-01 00:36:48.0280
# 4          1473  2020-02-01 00:32:30.5050  2020-02-01 00:57:04.3740
#
#    start station id  start station name  start station latitude  \
# 0              3199        Newport Pkwy               40.728745
# 1              3273        Manila & 1st               40.721651
# 2              3185           City Hall               40.717733
# 3              3185           City Hall               40.717733
# 4              3192  Liberty Light Rail               40.711242
#
#    start station longitude  end station id         end station name  \
# 0               -74.032108            3213           Van Vorst Park
# ...

# %%
raw15 = pd.read_csv(r"C:\Users\micha\Documents\uofa-phx-data-pt-02-2020-u-c\02-Homework\20-Tableau\Data1\extracted\JC-202003-citibike-tripdata.csv\JC-202003-citibike-tripdata.csv")
df15 = pd.DataFrame(raw15)
df15.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           389  2020-03-01 00:14:07.0000  2020-03-01 00:20:36.0880
# 1           242  2020-03-01 00:48:06.4390  2020-03-01 00:52:08.9870
# 2           124  2020-03-01 01:08:46.4880  2020-03-01 01:10:51.2780
# 3           104  2020-03-01 01:22:35.4790  2020-03-01 01:24:20.2470
# 4           228  2020-03-01 01:39:20.2680  2020-03-01 01:43:09.1380
#
#    start station id start station name  start station latitude  \
# 0              3202       Newport PATH               40.727224
# 1              3185          City Hall               40.717733
# 2              3272       Jersey & 3rd               40.723332
# 3              3202       Newport PATH               40.727224
# 4              3194    McGinley Square               40.725340
#
#    start station longitude  end station id   end station name  \
# 0               -74.033759            3203      Hamilton Park
# ...

# %%
raw16 = pd.read_csv(r"C:\Users\micha\Documents\uofa-phx-data-pt-02-2020-u-c\02-Homework\20-Tableau\Data1\extracted\JC-202004-citibike-tripdata.csv\JC-202004-citibike-tripdata.csv")
df16 = pd.DataFrame(raw16)
df16.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1437  2020-04-01 01:06:20.6300  2020-04-01 01:30:17.9680
# 1           264  2020-04-01 05:02:42.0570  2020-04-01 05:07:06.1260
# 2           254  2020-04-01 06:20:28.1190  2020-04-01 06:24:42.1380
# 3           429  2020-04-01 06:33:30.5170  2020-04-01 06:40:40.1990
# 4           805  2020-04-01 06:38:32.9220  2020-04-01 06:51:58.2050
#
#    start station id start station name  start station latitude  \
# 0              3678      Fairmount Ave               40.725726
# 1              3207        Oakland Ave               40.737604
# 2              3678      Fairmount Ave               40.725726
# 3              3195            Sip Ave               40.730897
# 4              3193       Lincoln Park               40.724605
#
#    start station longitude  end station id end station name  \
# 0               -74.071959            3678    Fairmount Ave
# ...

# %%
raw17 = pd.read_csv(r"C:\Users\micha\Documents\uofa-phx-data-pt-02-2020-u-c\02-Homework\20-Tableau\Data1\extracted\JC-202005-citibike-tripdata.csv\JC-202005-citibike-tripdata.csv")
df17 = pd.DataFrame(raw17)
df17.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           349  2020-05-01 00:09:45.5860  2020-05-01 00:15:35.2930
# 1           138  2020-05-01 01:11:22.5280  2020-05-01 01:13:41.2460
# 2           229  2020-05-01 05:31:29.5350  2020-05-01 05:35:19.2400
# 3           261  2020-05-01 05:51:39.3960  2020-05-01 05:56:00.9370
# 4           168  2020-05-01 06:06:31.9510  2020-05-01 06:09:20.1410
#
#    start station id          start station name  start station latitude  \
# 0              3195                     Sip Ave               40.730897
# 1              3792  Columbus Dr at Exchange Pl               40.716870
# 2              3483               Montgomery St               40.719420
# 3              3278            Monmouth and 6th               40.725685
# 4              3194             McGinley Square               40.725340
#
#    start station longitude  end station id end station name  \
# ...

# %%
raw18 = pd.read_csv(r"C:\Users\micha\Documents\uofa-phx-data-pt-02-2020-u-c\02-Homework\20-Tableau\Data1\extracted\JC-202006-citibike-tripdata.csv\JC-202006-citibike-tripdata.csv")
df18 = pd.DataFrame(raw18)
df18.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           122  2020-06-01 00:02:21.7500  2020-06-01 00:04:24.3250
# 1          1282  2020-06-01 00:12:27.1090  2020-06-01 00:33:50.0540
# 2           186  2020-06-01 01:19:59.2090  2020-06-01 01:23:05.8930
# 3           131  2020-06-01 01:26:42.2050  2020-06-01 01:28:53.8040
# 4           266  2020-06-01 01:27:33.7090  2020-06-01 01:32:00.1890
#
#    start station id          start station name  start station latitude  \
# 0              3792  Columbus Dr at Exchange Pl               40.716870
# 1              3198            Heights Elevator               40.748716
# 2              3275              Columbus Drive               40.718355
# 3              3267                Morris Canal               40.712419
# 4              3639                  Harborside               40.719252
#
#    start station longitude  end station id  end station name  \
# ...

# %%
df_all =  pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, df17, df18], ignore_index=True)
df_all.tail()
# Out:
#         tripduration                 starttime                  stoptime  \
# 542909          2828  2020-06-30 23:53:19.7380  2020-07-01 00:40:28.5760
# 542910          2729  2020-06-30 23:54:44.0100  2020-07-01 00:40:13.6470
# 542911          2788  2020-06-30 23:54:52.1920  2020-07-01 00:41:20.6500
# 542912          2702  2020-06-30 23:56:14.6650  2020-07-01 00:41:16.7820
# 542913          2649  2020-06-30 23:57:46.1490  2020-07-01 00:41:55.5060
#
#         start station id start station name  start station latitude  \
# 542909              3199       Newport Pkwy               40.728745
# 542910              3199       Newport Pkwy               40.728745
# 542911              3199       Newport Pkwy               40.728745
# 542912              3199       Newport Pkwy               40.728745
# 542913              3199       Newport Pkwy               40.728745
#
#         start station longitude  end station id end station name  \
# ...

# %%
df_all['gender']
# Out:
# 0         1
# 1         2
# 2         1
# 3         0
# 4         0
#          ..
# 542909    0
# 542910    0
# 542911    0
# 542912    0
# 542913    2
# Name: gender, Length: 542914, dtype: int64

# %%
df_all['Gender'] = df_all['gender'].replace([0,1,2],['unknown',"Male","Female"])
df_all = df_all.drop('gender',1)
df_all["distance"] = ''
df_all.tail()
# Out:
#         tripduration                 starttime                  stoptime  \
# 542909          2828  2020-06-30 23:53:19.7380  2020-07-01 00:40:28.5760
# 542910          2729  2020-06-30 23:54:44.0100  2020-07-01 00:40:13.6470
# 542911          2788  2020-06-30 23:54:52.1920  2020-07-01 00:41:20.6500
# 542912          2702  2020-06-30 23:56:14.6650  2020-07-01 00:41:16.7820
# 542913          2649  2020-06-30 23:57:46.1490  2020-07-01 00:41:55.5060
#
#         start station id start station name  start station latitude  \
# 542909              3199       Newport Pkwy               40.728745
# 542910              3199       Newport Pkwy               40.728745
# 542911              3199       Newport Pkwy               40.728745
# 542912              3199       Newport Pkwy               40.728745
# 542913              3199       Newport Pkwy               40.728745
#
#         start station longitude  end station id end station name  \
# ...

# %%
df_all.isnull().any()
# Out:
# tripduration               False
# starttime                  False
# stoptime                   False
# start station id           False
# start station name         False
# start station latitude     False
# start station longitude    False
# end station id             False
# end station name           False
# end station latitude       False
# end station longitude      False
# bikeid                     False
# usertype                   False
# birth year                 False
# Gender                     False
# distance                   False
# dtype: bool

# %%
df_all.to_csv(r"C:\Users\micha\Documents\uofa-phx-data-pt-02-2020-u-c\02-Homework\20-Tableau\Data1\extracted\citibike-tripdata.csv", index_label = "TripID")
